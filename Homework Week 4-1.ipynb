# %%
#1. **What does one need to do to use a module?** ( Import it) ( Collection of code or functions)

#2. Name a Module (not the DateTime Nodule) we looked at and write a line or 2 of code as an example using this module. (Math module)
3.  X = 12
4.  Y = 10
5. Print( x + y)
6. Output 12


#3. **What is a benefit of using Exception handling?**    (Python will normally stop and generate an error message when something goes wrong. It lets you execute code when there is no error, lets you execute code, regardless of the result of the try- and except blocks.)

#4. **what are the 4 components used for Python Exception Handling?**  ( Try , Except, Else, Finally)

#5. **NumPy arrays are like what Python data type?**  (It stores values in square brackets under a variable name similar to list.)

#6. **What is one of the main benefits of using NumPy arrays.** (Occupy less memory, Faster, More convenient)

#7. **What is one of the main requirements about the 'dtype' of NumPy arrays?** (store only the same data type.)

#8. **Of the 10 uses of NumPy, name** - (Arithmetic operations and stacking.)

#9. **Name one of the other libraries we'll use with NumPy?** (Pandas and Matplotlib.)

#10. **What is the shape of NumPy arrays?** (The number of dimensions and items in an array defines its SHAPE.)

#11. **What is a Tensor?** (An array with three dimensions.)

#12. **Name a reason why it's better using NumPy for Data Analysis than using a Python List?** (speed and memory)

#13. **When creating an "empty" array, where do the elements come from?** (it comes from memory )

# %%
# Create an if statement 
a = 24
if a >= 25:
    print('renting a car is more affortable')
if a<25:
    print('renting a car is very expensive')
# Out:
# renting a car is very expensive

# %%
#Create and chain an if-else statement

age = 30
if age >=25:
    print("Renting a car is more affordable")
if age <25 & age >= 18:
    print("Renting a car is very expensive")
else: 
    print("You cannot legally rent a car.")

#need help, why does it print 2 statements for numbers greater than 25?
# Out:
# Renting a car is more affordable
# You cannot legally rent a car.

# %%
#Loop over the following string 

mycomic = "The quick brown fox jumps over the lazy dog"
count = 0
for character in mycomic:
    count +=1
    if character in "aeiouAEIOU":
        print(character)
        print(count)
# Out:
# e
# 3
# u
# 6
# i
# 7
# o
# 13
# o
# 18
# u
# 22
# o
# 27
# e
# 29
# e
# 34
# a
# 37
# o
# 42

# %%
#Write a nested loop that prints out every piece of clothing from the couture list

couturelist = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"]
panettonelist = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for x in couture:
        for y in panettone:
                print(x,y)
# Out:
# trousers maple
# trousers gunmetal blue
# trousers Dark Sapphire
# trousers burnt sienna
# trousers fuchsia
# trousers cerise
# trousers auburn
# trousers aqua
# blouse maple
# blouse gunmetal blue
# blouse Dark Sapphire
# blouse burnt sienna
# blouse fuchsia
# blouse cerise
# blouse auburn
# blouse aqua
# bandana maple
# bandana gunmetal blue
# bandana Dark Sapphire
# bandana burnt sienna
# bandana fuchsia
# bandana cerise
# bandana auburn
# bandana aqua
# cumber band maple
# cumber band gunmetal blue
# cumber band Dark Sapphire
# cumber band burnt sienna
# cumber band fuchsia
# cumber band cerise
# cumber band auburn
# cumber band aqua
# blazer maple
# blazer gunmetal blue
# blazer Dark Sapphire
# blazer burnt sienna
# blazer fuchsia
# blazer cerise
# blazer auburn
# blazer aqua
# vest maple
# vest gunmetal blue
# vest Dark Sapphire
# vest burnt sienna
# vest fuchsia
# vest cerise
# vest auburn
# vest aqua
# french beret maple
# french beret gunmetal blue
# ...

# %%
##Use range as a loop to calculate the sum of all the numbers from 1 to 100

count = 0
for i in range(1,101):
    count = count + i 
    print(count)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
# 5050

# %%
#Print the second item in this fruits list. ["apple", "banana", "cherry"]

fruitlist = ["apple", "banana", "cherry"]
print(fruitlist[1])

#Use the append method to add "orange" to the fruits list.

fruitlist = ["apple", "banana", "cherry"]
fruitlist.append("orange")
print(fruitlist)

#Use the insert method to add "lemon" as the second item in the fruits list

fruitlist = ["apple", "banana", "cherry"]
fruitlist.insert(1,'lemon')
print(fruitlist)

#Use the remove method to remove "banana" from the fruits list. 

fruitlist = ["apple", "banana", "cherry"]
fruitlist.remove('banana')
print(fruitlist)

print('ineedspace')
#Use negative indexing to print the 3rd and 2nd to last items in the list

fruitlist =  ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruitlist[-5])
print(fruitlist[-2])

#Use a range of indexes to print the third, fourth, and fifth item in the list

fruitlist =  ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruitlist[2:5])

#Use the correct syntax to print the number of items in the list.

fruitlist =  ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(len(fruitlist))

#Use the correct syntax to sort this list in reverse order
fruitslist =  ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruitlist.reverse()
print(fruitlist)
# Out:
# banana
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'lemon', 'banana', 'cherry']
# ['apple', 'cherry']
# ineedspace
# cherry
# melon
# ['cherry', 'orange', 'kiwi']
# 7
# ['mango', 'melon', 'kiwi', 'orange', 'cherry', 'banana', 'apple']

# %%
#Use the DateTime module to get Current Date and Time, and save it to a variable. 
import datetime as dt
a = dt.datetime.now()
print(a)

#Then extract just the Full month name form that variable.
import datetime as dt
a = dt.datetime.now()
print(a.strftime("%B"))

#Write a simple function that takes 2 parameters -- a first name and a day name.
def myFunction(nombre, dia = 'Valentines Day'):
    print('Hi,', nombre, '!', 'Happy', dia, '!')

myFunction(nombre = 'Mea')

#Invoke this function with 2 variables.
def myFunction(nombre, dia = 'Sunday'):
    print('Hi,', nombre, '!', 'Happy', dia, '!')

myFunction('My Savvy classmates', 'Valentines Day')

#Invoke this function with 1 variable only.
def myFunction(nombre, dia = 'wednesday'):
    print('Hi,', nombre, '!', 'Happy', dia, '!')

myFunction(nombre = 'Shafi')
# Out:
# 2024-02-14 20:50:25.023721
# February
# Hi, Mea ! Happy Valentines Day !
# Hi, My Savvy classmates ! Happy Valentines Day !
# Hi, Shafi ! Happy wednesday !

# %%
#Write a block of code to handle one of the most common Python exception errors.
#Select one of the common errors from the curriculum section on Python Exception handling.
#Have your code example use the try, except, else, and finally components.

# %%
try:
    print('Lamar Jackson')
except NameError:
    print("Variable x is not defined")
else:
    print("Something else went wrong")
finally: 
    print('baltimore ravens')
# Out:
# Lamar Jackson
# Something else went wrong
# baltimore ravens
